# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="meta-llama/Llama-2-7b-chat-hf")
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [01:12<00:00, 36.19s/it]

# %%
pipe("You are a helpful virtual assistant who gives polite and helpful answers to user questions. Question: What is the capital of France? Answer:")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\UserFiles\Academics\Berkeley\fa23\CS 285\cs285-proj-fa23\experimental-code\llama_2_script.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/UserFiles/Academics/Berkeley/fa23/CS%20285/cs285-proj-fa23/experimental-code/llama_2_script.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> pipe("You are a helpful virtual assistant who gives polite and helpful answers to user questions. Question: What is the capital of France? Answer:")
#
# File d:\UserFiles\Programming\Anaconda\envs\minedojo\lib\site-packages\transformers\pipelines\text_generation.py:208, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     167 def __call__(self, text_inputs, **kwargs):
#     168     """
#     169     Complete the prompt(s) given as inputs.
#     170
#    (...)
#     206           ids of the generated text.
#     207     """
# ...
